# %% [markdown]
# <a href="https://colab.research.google.com/github/fadhlis/statistika-tim1/blob/master/Ukuran_Persebaran_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <style type="text/css">
# <!--
# .style2 {font-family: Calibri}
# -->
# </style>
#
# <body>
# <p class="style2"><strong>Nama :</strong> Aryan  Nasikhul Amin<br />
# <strong>NIM : </strong>1941727014</p>
# <h2 class="style2">UKURAN PENYEBARAN DATA (MEASURES OF  DISPERSION)</h2>
# <p class="style2">Mean, median, dan mode adalah ukuran pusat dari data.  Beberapa karakteristik dari satu set data mungkin tidak akan mucul hanya dari  pemeriksaan ukuran-ukuran tendensi sentral ini. Misalnya, perhatikan jumlah siswa laki-laki dan perempuan yang putus sekolah di seluruh provinsi di Indonesia dalam dua tahun pelajaran yang ditunjukkan pada tabel berikut.</p>
#   <table cellspacing="0" cellpadding="0">
#   <col width="69" />
#   <col width="128" />
#   <col width="171" span="2" />
#   <tr height="40">
#     <td width="69" height="40" align="center" valign="middle"><span class="style1"><strong>No Kelas</strong></span></td>
#     <td width="128" align="center" valign="middle"><span class="style1"><strong>Kelas Interval</strong></span></td>
#     <td width="171" align="center" valign="middle"><span class="style1"><strong>Frekuensi    (f) 1 <br />
#     Tahun Ajaran 2016/2017</strong></span></td>
#     <td width="171" align="center" valign="middle"><span class="style1"><strong>Frekuensi    (f) 2 <br />
#     Tahun Ajaran 2017/2018</strong></span></td>
#   </tr>
#   <tr height="20">
#     <td height="20" align="center" valign="middle"><span class="style1"><strong>1</strong></span></td>
#     <td align="center" valign="middle"><span class="style2">1-1000</span></td>
#     <td align="center" valign="middle"><span class="style2">20</span></td>
#     <td align="center" valign="middle"><span class="style2">24</span></td>
#   </tr>
#   <tr height="20">
#     <td height="20" align="center" valign="middle"><span class="style1"><strong>2</strong></span></td>
#     <td align="center" valign="middle"><span class="style2">1001-2000</span></td>
#     <td align="center" valign="middle"><span class="style2">9</span></td>
#     <td align="center" valign="middle"><span class="style2">7</span></td>
#   </tr>
#   <tr height="20">
#     <td height="20" align="center" valign="middle"><span class="style1"><strong>3</strong></span></td>
#     <td align="center" valign="middle"><span class="style2">2001-3000</span></td>
#     <td align="center" valign="middle"><span class="style2">2</span></td>
#     <td align="center" valign="middle"><span class="style2">1</span></td>
#   </tr>
#   <tr height="20">
#     <td height="20" align="center" valign="middle"><span class="style1"><strong>4</strong></span></td>
#     <td align="center" valign="middle"><span class="style2">3001-4000</span></td>
#     <td align="center" valign="middle"><span class="style2">2</span></td>
#     <td align="center" valign="middle"><span class="style2">1</span></td>
#   </tr>
#   <tr height="20">
#     <td height="20" align="center" valign="middle"><span class="style1"><strong>5</strong></span></td>
#     <td align="center" valign="middle"><span class="style2">40001-5000</span></td>
#     <td align="center" valign="middle"><span class="style2">0</span></td>
#     <td align="center" valign="middle"><span class="style2">1</span></td>
#   </tr>
#   <tr height="20">
#     <td height="20" align="center" valign="middle"><span class="style1"><strong>6</strong></span></td>
#     <td align="center" valign="middle"><span class="style2">5001-6000</span></td>
#     <td align="center" valign="middle"><span class="style2">1</span></td>
#     <td align="center" valign="middle"><span class="style2">0</span></td>
#   </tr>
# </table>
# <br>
# <table cellspacing="0" cellpadding="0">
#   <col width="156" />
#   <col width="64" span="9" />
#   <tr height="20">
#     <td width="156" height="20" align="center" valign="middle"><strong>Tahun    Ajaran 2016/2017</strong></td>
#     <td width="64" align="center" valign="middle">20</td>
#     <td width="64" align="center" valign="middle">9</td>
#     <td width="64" align="center" valign="middle">2</td>
#     <td width="64" align="center" valign="middle">2</td>
#     <td width="64" align="center" valign="middle">0</td>
#     <td width="64" align="center" valign="middle">1</td>
#     <td width="64" align="center" valign="middle"><strong>Modus :</strong> 5.7</td>
#     <td width="64" align="center" valign="middle"><strong>Median :</strong> 2</td>
#     <td width="64" align="center" valign="middle"><strong>Modus :</strong> 2</td>
#   </tr>
#   <tr height="20">
#     <td height="20" align="center" valign="middle"><strong>Tahun Ajaran    2017/2018</strong></td>
#     <td align="center" valign="middle">24</td>
#     <td align="center" valign="middle">7</td>
#     <td align="center" valign="middle">1</td>
#     <td align="center" valign="middle">1</td>
#     <td align="center" valign="middle">1</td>
#     <td align="center" valign="middle">0</td>
#     <td align="center" valign="middle"><strong>Mean :</strong> 5.7</td>
#     <td align="center" valign="middle"><strong>Median :</strong> 1</td>
#     <td align="center" valign="middle"><strong>Modus :</strong> 1</td>
#   </tr>
# </table>
#   <br>
# <p class="style2">Mean, median, dan mode jumlah siswa laki-laki dan perempuan yang putus sekolah di seluruh provinsi di Indonesia dalam dua tahun pelajaran identik, pemeriksaan jumlah siswa menunjukkan bahwa sama-sama tersebar luas. Untuk mengukur penyebaran data, kami mendefinisikan nilai statistik dikenal sebagai variasi dan standar deviasi.</p>
# <h3 class="style2">Standar Deviasi dan Varians</h3>
# <p class="style2">Pengukuran yang paling sering dilakukan untuk mengukur  penyebaran data adalah standar deviasi. Standar deviasi adalah pengukuran yang  digunakan untuk mengetahui bagaimana konsentrasi data terhadap mean, atau  dengan kata lain untuk mengetahui deviasi (penyimpangan) masing-masing data  terhadap mean. Semakin data terkonsentrasi pada mean, maka tingkat penyimpangan  data tersebut terhadap mean adalah kecil.<br />
#   Standar deviasi digunakan untuk mengetahui apakah sampel  data yang diambil mewakili seluruh populasi. Karena mencari data yang tepat  untuk suatu populasi sangat sulit untuk dilakukan. Maka dari itu perlu  menggunakan sampel data yang dapat mewakili seluruh populasi sehingga mempermudah  untuk melakukan penelitian atau suatu tugas. <br />
#   Sebagai gambaran, jika seseorang ingin mengetahui berat  badan anak laki-laki berusia 10-12 tahun di suatu sekolah, maka yang perlu  dilakukan adalah mencari tahu berat beberapa orang dan menghitung rata-rata  serta standar deviasinya. Dari perhitungan tersebut akan diketahui nilai yang  dapat mewakili seluruh populasi.<br />
#   Untuk mengetahui nilai standar deviasi harus dihitung nilai  varians terlebih dahulu. Cara untuk menghitung varians dijelaskan sebagai  berikut:</p>
#   1. Hitung mean populasi, μ.<br />
# 	2. Kurangi masing-masing anggota set dengan mean dari masing-masing nilai dalam batch. Ini menghasilkan satu set deviasi, d (di mana d = x - μ). Ambil kuadrat dari deviasi ini, d^2.<br />
# 	3. Jumlahkan seluruh nilai deviasi kuadrat, dan bagi dengan banyaknya anggota set, n. Maka akan diperoleh varians, σ^2.<br />
# 	4. Untuk mendapatkan standar deviasi σ, hitung akar kuadrat dari varians.<br />
#
#  Untuk perhitungan varians dan standar deviasi pada sampel, varians dilambangkan dengan S^2 dan standar deviasi dilambangkan dengan S. Pada persamaan perhitungan sampel, pembagi n berubah menjadi n – 1. Hal itu disebut dengan "Bessel's correction". Sehingga diperoleh persamaan sebagai berikut :<br><br>
#   <a href="https://imgbb.com/"><img src="https://i.ibb.co/1G2bdWy/image.png" alt="image" border="0"></a><br /><br>
#   Berikut ini adalah contoh perhitungan varians dan standar deviasi dari contoh kasus tabel diatas:<br />
#   Data Tahun Ajaran 2016/2017 :  20, 9, 2, 2, 0, 1<br />
#  <a href="https://imgbb.com/"><img src="https://i.ibb.co/pRvMzGQ/image.png" alt="image" border="0"></a><br />
#  Sehingga diperoleh standar deviasi dari Data Tahun Ajaran 2016/2017 adalah 7.03<br />
#   Data Tahun Ajaran 2017/2018 :  24, 7, 1, 1, 1, 0<br />
# <a href="https://imgbb.com/"><img src="https://i.ibb.co/gJ7mT8t/image.png" alt="image" border="0"></a><br />
# Sehingga diperoleh standar deviasi dari Data Tahun Ajaran 2017/2018 adalah 8.5<br />
# Dari perbandingan standar deviasi yang telah dihitung sebelumnya, maka dapat disimpulkan bahwa jumlah siswa laki-laki dan perempuan yang putus sekolah di Pulau Jawa di Indonesia dalam dua tahun pelajaran adalah beragam atau bervariasi.
