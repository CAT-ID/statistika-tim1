# %% [markdown]
# <a href="https://colab.research.google.com/github/fadhlis/statistika-tim1/blob/master/Ukuran_Persebaran_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <style type="text/css">
# <!--
# .style2 {font-family: Calibri}
# -->
# </style>
# </head>
#
# <body>
# <p class="style2"><strong>Nama :</strong> Aryan  Nasikhul Amin<br />
# <strong>NIM : </strong>1941727014</p>
# <h2 class="style2">UKURAN PENYEBARAN DATA (MEASURES OF  DISPERSION)</h2>
# <p class="style2">Mean, median, dan mode adalah ukuran pusat dari data.  Beberapa karakteristik dari satu set data mungkin tidak akan mucul hanya dari  pemeriksaan ukuran-ukuran tendensi sentral ini. Misalnya, perhatikan jumlah  siswa laki-laki dan perempuan yang putus sekolah di Pulau Jawa di Indonesia  dalam dua tahun pelajaran yang ditunjukkan pada tabel berikut.</p>
#   <table cellspacing="0" cellpadding="0">
#   <col width="64" />
#   <col width="135" />
#   <col width="97" />
#   <col width="90" />
#   <tr height="20">
#     <td width="64" height="60" rowspan="3" align="center" valign="middle"><strong>No</strong></td>
#     <td width="135" rowspan="3" align="center" valign="middle"><strong>Provinsi</strong></td>
#     <td width="187" colspan="2" rowspan="2" align="center" valign="middle"><strong>Jumlah dalam    Tahun Ajaran<br />
#       (Laki-laki + Perempuan)</strong></td>
#   </tr>
#   <tr height="20"> </tr>
#   <tr height="20">
#     <td height="20" align="center" valign="middle"><strong>2016/2017</strong></td>
#     <td align="center" valign="middle"><strong>2017/2018</strong></td>
#   </tr>
#   <tr height="20">
#     <td height="20" align="center" valign="middle"><strong>1</strong></td>
#     <td align="left" valign="middle">Prov. D.K.I. Jakarta</td>
#     <td align="center" valign="middle">606</td>
#     <td align="center" valign="middle">570</td>
#   </tr>
#   <tr height="20">
#     <td height="20" align="center" valign="middle"><strong>2</strong></td>
#     <td align="left" valign="middle">Prov. Jawa Barat</td>
#     <td align="center" valign="middle">5,626</td>
#     <td align="center" valign="middle">4,779</td>
#   </tr>
#   <tr height="20">
#     <td height="20" align="center" valign="middle"><strong>3</strong></td>
#     <td align="left" valign="middle">Prov. Jawa Tengah</td>
#     <td align="center" valign="middle">2,618</td>
#     <td align="center" valign="middle">1,566</td>
#   </tr>
#   <tr height="20">
#     <td height="20" align="center" valign="middle"><strong>4</strong></td>
#     <td align="left" valign="middle">Prov. D.I. Yogyakarta</td>
#     <td align="center" valign="middle">260</td>
#     <td align="center" valign="middle">143</td>
#   </tr>
#   <tr height="20">
#     <td height="20" align="center" valign="middle"><strong>5</strong></td>
#     <td align="left" valign="middle">Prov. Jawa Timur</td>
#     <td align="center" valign="middle">3,991</td>
#     <td align="center" valign="middle">3,850</td>
#   </tr>
# </table><br>
# <table border="2" cellpadding="0" cellspacing="0">
#   <col width="70" span="9" />
#   <tr height="20">
#     <td width="70" height="20" align="center" valign="middle" class="style2"><strong>2016/2017</strong></td>
#     <td width="70" align="center" valign="middle" class="style2">260</td>
#     <td width="70" align="center" valign="middle" class="style2">606</td>
#     <td width="70" align="center" valign="middle" class="style2">2618</td>
#     <td width="70" align="center" valign="middle" class="style2">3991</td>
#     <td width="70" align="center" valign="middle" class="style2">5626</td>
#     <td width="70" align="left" valign="middle" class="style2"><strong>Mean : </strong>2620.2</td>
#     <td width="70" align="left" valign="middle" class="style2"><strong>Median : </strong>2618</td>
#     <td width="70" align="left" valign="middle" class="style2"><strong>Modus : </strong>Tidak Ada</td>
#   </tr>
#   <tr height="20">
#     <td height="20" align="center" valign="middle" class="style2"><strong>2017/2018</strong></td>
#     <td align="center" valign="middle" class="style2">143</td>
#     <td align="center" valign="middle" class="style2">570</td>
#     <td align="center" valign="middle" class="style2">1566</td>
#     <td align="center" valign="middle" class="style2">3850</td>
#     <td align="center" valign="middle" class="style2">4779</td>
#     <td align="left" valign="middle" class="style2"><strong>Mean :</strong> 2181.6</td>
#     <td align="left" valign="middle" class="style2"><strong>Median :</strong> 1566</td>
#     <td align="left" valign="middle" class="style2"><strong>Modus : </strong>Tidak Ada</td>
#   </tr>
# </table>
# <p class="style2">Mean, median, dan mode jumlah siswa laki-laki dan perempuan  yang putus sekolah di Pulau Jawa di Indonesia dalam dua tahun pelajaran berbeda,  pemeriksaan jumlah siswa menunjukkan bahwa sama-sama tersebar luas. Untuk  mengukur penyebaran data, kami mendefinisikan nilai statistik dikenal sebagai variasi  dan standar deviasi.</p>
# <h3 class="style2">Standar Deviasi dan Varians</h3>
# <p class="style2">Pengukuran yang paling sering dilakukan untuk mengukur  penyebaran data adalah standar deviasi. Standar deviasi adalah pengukuran yang  digunakan untuk mengetahui bagaimana konsentrasi data terhadap mean, atau  dengan kata lain untuk mengetahui deviasi (penyimpangan) masing-masing data  terhadap mean. Semakin data terkonsentrasi pada mean, maka tingkat penyimpangan  data tersebut terhadap mean adalah kecil.<br />
#   Standar deviasi digunakan untuk mengetahui apakah sampel  data yang diambil mewakili seluruh populasi. Karena mencari data yang tepat  untuk suatu populasi sangat sulit untuk dilakukan. Maka dari itu perlu  menggunakan sampel data yang dapat mewakili seluruh populasi sehingga mempermudah  untuk melakukan penelitian atau suatu tugas. <br />
#   Sebagai gambaran, jika seseorang ingin mengetahui berat  badan anak laki-laki berusia 10-12 tahun di suatu sekolah, maka yang perlu  dilakukan adalah mencari tahu berat beberapa orang dan menghitung rata-rata  serta standar deviasinya. Dari perhitungan tersebut akan diketahui nilai yang  dapat mewakili seluruh populasi.<br />
#   Untuk mengetahui nilai standar deviasi harus dihitung nilai  varians terlebih dahulu. Cara untuk menghitung varians dijelaskan sebagai  berikut:</p>
#   1. Hitung mean populasi, μ.<br />
# 	2. Kurangi masing-masing anggota set dengan mean dari masing-masing nilai dalam batch. Ini menghasilkan satu set deviasi, d (di mana d = x - μ). Ambil kuadrat dari deviasi ini, d^2.<br />
# 	3. Jumlahkan seluruh nilai deviasi kuadrat, dan bagi dengan banyaknya anggota set, n. Maka akan diperoleh varians, σ^2.<br />
# 	4. Untuk mendapatkan standar deviasi σ, hitung akar kuadrat dari varians.<br />
#
#  Untuk perhitungan varians dan standar deviasi pada sampel, varians dilambangkan dengan S^2 dan standar deviasi dilambangkan dengan S. Pada persamaan perhitungan sampel, pembagi n berubah menjadi n – 1. Hal itu disebut dengan "Bessel's correction". Sehingga diperoleh persamaan sebagai berikut :
#   ![alt text](https://raw.githubusercontent.com/fadhlis/statistika-tim1/master/persebaran.JPG)<br />
#   Berikut ini adalah contoh perhitungan varians dan standar deviasi dari contoh kasus tabel diatas:<br />
#   Data Tahun Ajaran 2016/2017 :  260, 606, 2618, 3991, 5626<br />
#   ![alt text](https://raw.githubusercontent.com/fadhlis/statistika-tim1/master/persebaran1.JPG)<br />
#   Sehingga diperoleh standar deviasi dari Data Tahun Ajaran 2016/2017 adalah 2026.89 atau 2027<br />
#   Data Tahun Ajaran 2017/2018 :  143, 570, 1566, 3850, 4779<br />
#   ![alt text](https://raw.githubusercontent.com/fadhlis/statistika-tim1/master/persebaran2.JPG)<br />
#   Sehingga diperoleh standar deviasi dari Data Tahun Ajaran 2017/2018 adalah 1962.11 atau 1962<br />
#  Dari perbandingan standar deviasi yang telah dihitung sebelumnya, maka dapat disimpulkan bahwa jumlah siswa laki-laki dan perempuan yang putus sekolah di   Pulau Jawa di Indonesia dalam dua tahun pelajaran adalah beragam atau bervariasi.
